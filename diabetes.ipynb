# %% [markdown]
# <a href="https://colab.research.google.com/github/pravallikasri0229/pravallika-analyst-/blob/main/diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import seaborn as sn

# %%
data = pd.read_csv("/content/diabetes.csv - diabetes.csv.csv")

# %%
data.head()
# Out:
#    patient_number  cholesterol  glucose  hdl_chol  chol_hdl_ratio  age  \
# 0               1          193       77        49             3.9   19
# 1               2          146       79        41             3.6   19
# 2               3          217       75        54             4.0   20
# 3               4          226       97        70             3.2   20
# 4               5          164       91        67             2.4   20
#
#    gender  height  weight   bmi  systolic_bp  diastolic_bp  waist  hip  \
# 0  female      61     119  22.5          118            70     32   38
# 1  female      60     135  26.4          108            58     33   40
# 2  female      67     187  29.3          110            72     40   45
# 3  female      64     114  19.6          122            64     31   39
# 4  female      70     141  20.2          122            86     32   39
#
#    waist_hip_ratio     diabetes
# 0             0.84  No diabetes
# 1             0.83  No diabetes
# ...

# %% [markdown]
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# data['gender']=le.fit_transform(data['gender'])
# data['diabetes']=le.fit_transform(data['diabetes'])
# data.head()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data['gender']=le.fit_transform(data['gender'])
data['diabetes']=le.fit_transform(data['diabetes'])
data.head()
# Out:
#    patient_number  cholesterol  glucose  hdl_chol  chol_hdl_ratio  age  \
# 0               1          193       77        49             3.9   19
# 1               2          146       79        41             3.6   19
# 2               3          217       75        54             4.0   20
# 3               4          226       97        70             3.2   20
# 4               5          164       91        67             2.4   20
#
#    gender  height  weight   bmi  systolic_bp  diastolic_bp  waist  hip  \
# 0       0      61     119  22.5          118            70     32   38
# 1       0      60     135  26.4          108            58     33   40
# 2       0      67     187  29.3          110            72     40   45
# 3       0      64     114  19.6          122            64     31   39
# 4       0      70     141  20.2          122            86     32   39
#
#    waist_hip_ratio  diabetes
# 0             0.84         1
# 1             0.83         1
# ...

# %% [markdown]
# import numpy as np
# x = np.array(data.iloc[:,1:15])
# y = np.array(data['diabetes'])

# %%
import numpy as np
x = np.array(data.iloc[:,1:15])
y = np.array(data['diabetes'])

# %%
from sklearn.naive_bayes import GaussianNB
gnbc= GaussianNB()

# %% [markdown]
# from sklearn import model_selection
# xtrain,xtesr,ytrain,ytest=model_selection.train_test_split(x,y,train_size=0.75)
# gnbc.fit(xtrain,ytrain)

# %%
from sklearn import model_selection
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,train_size=0.75)
gnbc.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %% [markdown]
# ytest_predicted=gnbc.predict(xtest)

# %%
ytest_predicted=gnbc.predict(xtest)

# %%
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(gnbc,x,y,scoring="accuracy")
precision = cross_val_score(gnbc,x,y,scoring="precision_weighted")
recall = cross_val_score(gnbc,x,y,scoring="recall_weighted")
f1score = cross_val_score(gnbc,x,y,scoring="f1_weighted")
print("accuracy is : ", round(accuracy.mean()*100,2))
print("precison is : ", round(precision.mean()*100,2))
print("recall  is : ", round(recall.mean()*100,2))
print("f1 score  is : ", round(f1score.mean()*100,2))
# Out:
# accuracy is :  87.95
# precison is :  91.39
# recall  is :  87.95
# f1 score  is :  88.55
